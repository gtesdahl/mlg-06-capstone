# %% [markdown]
# # Book Rating Prediction

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-283c0d40bede> in <module>
# ----> 1 from fastai.vision import *
#       2 from fastai.metrics import error_rate
#
# ModuleNotFoundError: No module named 'fastai'

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import clear_output
from os import listdir
from os.path import isfile, join
np.random.seed(42)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Identify the bookIDs of downloaded images

# %%
#identify the book ids of the downloaded books
jpg_list = [f for f in listdir('./data/Grant/cover_images/') if isfile(join('./data/Grant/cover_images/', f)) and f != '4232.jpg']

downloaded_images = pd.Series(list(map(int,[i[:-4] for i in jpg_list])))

# %%
#count of book cover images
len(jpg_list)
# Out:
# 10599

# %% [markdown]
# ### Read Goodreads dataframe and merge with jpg list

# %%
goodreads = pd.read_csv('./data/Grant/books.csv', error_bad_lines=False)

#merges the goodreads reviews with the pic features
cover_df = goodreads[goodreads['bookID'].isin(list(downloaded_images))]
cover_df['file_name'] = cover_df['bookID'].astype(str) + '.jpg'
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# ### Create calculated targets

# %%
#rating mean norm
cover_df['average_rating_mean_norm'] = (cover_df['average_rating']-cover_df['average_rating'].mean())/cover_df['average_rating'].std()

#rating min-max norm
cover_df['average_rating_min_max'] = (cover_df['average_rating']-cover_df['average_rating'].min())/(cover_df['average_rating'].max()-cover_df['average_rating'].min())

#rating thirds
cover_df['average_rating_thirds'] = pd.qcut(cover_df['average_rating'], 3, labels=False).astype('str')

#count log
cover_df['ratings_count_log'] = (cover_df['ratings_count']+1).apply(np.log)

#count thirds
cover_df['ratings_count_thirds'] = pd.qcut(cover_df['ratings_count'], 3, labels=False).astype('str')

#summed thirds
cover_df['summed_thirds'] = (cover_df['average_rating_thirds'].astype('int') 
                                       + cover_df['ratings_count_thirds'].astype('int'))

cover_df.head()
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher file_name  average_rating_mean_norm  \
# 0        9/16/2006  Scholastic Inc.     1.jpg                  1.831714
# 1         9/1/2004  Scholastic Inc.     2.jpg                  1.600537
# 2        11/1/2003       Scholastic     4.jpg                  1.398257
# 3         5/1/2004  Scholastic Inc.     5.jpg                  1.802817
# 4        9/13/2004       Scholastic     8.jpg                  2.438554
#
#    average_rating_min_max average_rating_thirds  ratings_count_log  \
# 0                   0.914                     2          14.555394
# 1                   0.898                     2          14.582451
# 2                   0.884                     2           8.753687
# 3                   0.912                     2          14.665485
# 4                   0.956                     2          10.631736
#
#   ratings_count_thirds  summed_thirds
# 0                    2              4
# 1                    2              4
# 2                    2              4
# 3                    2              4
# 4                    2              4

# %% [markdown]
# # Average Rating Regression

# %% [markdown]
# ### Create image data object from cover_df and cover_images folder with a random validation set, 192x128 padded images, batch size of 12, and normalized pixel values

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('average_rating', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %% [markdown]
# ### Example book covers and their average ratings

# %%
data.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# ### Create CNN built from the resnet34 architecture

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %% [markdown]
# ### Identify a reasonable learning rate

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.76% [83/706 00:06<00:50 26.8874]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 1e-3

# %% [markdown]
# ### Fit for 5 epochs

# %%
learn.fit_one_cycle(5, slice(lr))

# %% [markdown]
# ### Save the initial model

# %%
learn.save('average_rating-stage-1')

# %% [markdown]
# ### Load in initial model for analysis & additional training

# %%
learn.load('average_rating-stage-1');

# %% [markdown]
# ### Show example predictions compared to actual

# %%
learn.show_results(rows=3, figsize=(10,9))

# %% [markdown]
# ### Gather predictions from the validation set

# %%
preds_average_rating = learn.get_preds()

# %% [markdown]
# ### Save actuals, predictions, and errors into a df

# %%
validation = pd.DataFrame(preds_average_rating[1].T.tolist(), columns=['average_rating_actual'])
validation['average_rating_predicted'] = preds_average_rating[0].T.tolist()[0]
validation['average_rating_error'] = validation['average_rating_actual'] - validation['average_rating_predicted']

validation.head()
# Out:
#    average_rating_actual  average_rating_predicted  average_rating_error
# 0                   3.19                  3.869111             -0.679111
# 1                   3.93                  3.913237              0.016763
# 2                   3.73                  3.861418             -0.131418
# 3                   3.68                  3.951411             -0.271411
# 4                   3.78                  3.879087             -0.099087

# %% [markdown]
# # Average Rating Mean Norm Regression

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('average_rating_mean_norm', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='81' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.47% [81/706 00:05<00:42 15.1550]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 2e-4

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.308100</td>
#       <td>1.496886</td>
#       <td>1.148950</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.180748</td>
#       <td>1.242882</td>
#       <td>1.034975</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.421306</td>
#       <td>1.108001</td>
#       <td>0.970337</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.290652</td>
#       <td>1.030852</td>
#       <td>0.927924</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.495838</td>
#       <td>1.013770</td>
#       <td>0.918401</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('average_rating_mean_norm-stage-1')

# %%
learn.load('average_rating_mean_norm-stage-1');

# %%
preds_average_rating_mean_norm = learn.get_preds()

# %%
validation['average_rating_mean_norm_actual'] = preds_average_rating_mean_norm[1].T.tolist()
validation['average_rating_mean_norm_predicted'] = preds_average_rating_mean_norm[0].T.tolist()[0]
validation['average_rating_mean_norm_error'] = validation['average_rating_mean_norm_actual'] - validation['average_rating_mean_norm_predicted']

# %% [markdown]
# # Avg Rating Min Max Norm Regression

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('average_rating_min_max', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='81' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.47% [81/706 00:05<00:42 13.9494]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=1e-3

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.307910</td>
#       <td>0.347857</td>
#       <td>0.576075</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.039625</td>
#       <td>0.013984</td>
#       <td>0.113795</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.013925</td>
#       <td>0.010188</td>
#       <td>0.097132</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.007281</td>
#       <td>0.005812</td>
#       <td>0.071279</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.004849</td>
#       <td>0.004581</td>
#       <td>0.061233</td>
#       <td>00:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('average_rating_min_max-stage-1')

# %%
learn.load('average_rating_min_max-stage-1');

# %%
preds_average_rating_min_max = learn.get_preds();

# %%
validation['average_rating_min_max_actual'] = preds_average_rating_min_max[1].T.tolist()
validation['average_rating_min_max_predicted'] = preds_average_rating_min_max[0].T.tolist()[0]
validation['average_rating_min_max_error'] = validation['average_rating_min_max_actual'] - validation['average_rating_min_max_predicted']

# %% [markdown]
# # Average Rating Segment Classification

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('average_rating_thirds')
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.46% [88/706 00:06<00:42 6.1529]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=2e-5

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.904176</td>
#       <td>1.431168</td>
#       <td>0.337423</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.791028</td>
#       <td>1.351459</td>
#       <td>0.352525</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.785292</td>
#       <td>1.319173</td>
#       <td>0.345446</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.794178</td>
#       <td>1.305964</td>
#       <td>0.350165</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.747106</td>
#       <td>1.308340</td>
#       <td>0.359132</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('average_rating_thirds-stage-1')

# %%
learn.load('average_rating_thirds-stage-1');

# %%
preds_average_rating_thirds = learn.get_preds()

# %% [markdown]
# ### Identify the predicted class based on the max probability for each sample in the validation set

# %%
learn.data.classes
# Out:
# ['0', '1', '2']

# %%
preds_average_rating_thirds_list = preds_average_rating_thirds[0].tolist()
average_rating_thirds_output = []
for probs in preds_average_rating_thirds_list:
    label = learn.data.classes[probs.index(max(probs))]
    average_rating_thirds_output.append(label)

# %%
validation['average_rating_thirds_actual'] = preds_average_rating_thirds[1].T.tolist()
validation['average_rating_thirds_predicted'] = average_rating_thirds_output
validation['average_rating_thirds_error'] = validation['average_rating_thirds_actual'].astype('int') - validation['average_rating_thirds_predicted'].astype('int')

# %% [markdown]
# # Rating Count Regression

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('ratings_count', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %%
learn.lr_find(stop_div=False, num_it=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.90% [197/706 00:12<00:32 9487051776.0000]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=2e-4

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7054154240.000000</td>
#       <td>26009393152.000000</td>
#       <td>57941.351562</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5897179648.000000</td>
#       <td>26009227264.000000</td>
#       <td>57939.980469</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5032824320.000000</td>
#       <td>26009055232.000000</td>
#       <td>57938.335938</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>12760754176.000000</td>
#       <td>26008940544.000000</td>
#       <td>57937.390625</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>14156739584.000000</td>
#       <td>26008954880.000000</td>
#       <td>57937.523438</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('ratings_count-stage-1')

# %%
learn.load('ratings_count-stage-1');

# %%
preds_ratings_count = learn.get_preds()

# %%
validation['ratings_count_actual'] = preds_ratings_count[1].T.tolist()
validation['ratings_count_predicted'] = preds_ratings_count[0].T.tolist()[0]
validation['ratings_count_error'] = validation['ratings_count_actual'] - validation['ratings_count_predicted']

# %% [markdown]
# # Ratings Count Log Regression

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('ratings_count_log', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.46% [88/706 00:05<00:41 169.9020]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=6e-3

# %%
learn.fit_one_cycle(8, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>11.261992</td>
#       <td>8.519144</td>
#       <td>2.847971</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.746693</td>
#       <td>7.158693</td>
#       <td>2.624527</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.173185</td>
#       <td>6.576440</td>
#       <td>2.516423</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.439196</td>
#       <td>6.902674</td>
#       <td>2.571049</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.685098</td>
#       <td>6.150492</td>
#       <td>2.433302</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.157009</td>
#       <td>6.343578</td>
#       <td>2.467921</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.830533</td>
#       <td>6.231979</td>
#       <td>2.444824</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.034369</td>
#       <td>6.312810</td>
#       <td>2.462475</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('ratings_count_log-stage-1')

# %%
learn.load('ratings_count_log-stage-1');

# %%
preds_ratings_count_log = learn.get_preds()

# %%
validation['ratings_count_log_actual'] = preds_ratings_count_log[1].T.tolist()
validation['ratings_count_log_predicted'] = preds_ratings_count_log[0].T.tolist()[0]
validation['ratings_count_log_error'] = validation['ratings_count_log_actual'] - validation['ratings_count_log_predicted']

# %% [markdown]
# # Ratings Count Segment Classification

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('ratings_count_thirds')
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.04% [85/706 00:05<00:42 4.3836]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=7e-4

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.644649</td>
#       <td>1.292829</td>
#       <td>0.370930</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.230669</td>
#       <td>1.123699</td>
#       <td>0.391222</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.102447</td>
#       <td>1.091656</td>
#       <td>0.397829</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.084685</td>
#       <td>1.064058</td>
#       <td>0.417178</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.047142</td>
#       <td>1.065024</td>
#       <td>0.419066</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('ratings_count_thirds-stage-1')

# %%
learn.load('ratings_count_thirds-stage-1');

# %%
preds_ratings_count_thirds = learn.get_preds()

# %%
preds_ratings_count_thirds_list = preds_ratings_count_thirds[0].tolist()
ratings_count_thirds_output = []
for probs in preds_ratings_count_thirds_list:
    label = learn.data.classes[probs.index(max(probs))]
    ratings_count_thirds_output.append(label)

# %%
validation['ratings_count_thirds_actual'] = preds_ratings_count_thirds[1].T.tolist()
validation['ratings_count_thirds_predicted'] = ratings_count_thirds_output
validation['ratings_count_thirds_error'] = validation['ratings_count_thirds_actual'].astype('int') - validation['ratings_count_thirds_predicted'].astype('int')

# %% [markdown]
# # Summed Thirds Regression

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('summed_thirds', label_cls=FloatList)
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))

# %%
learn = cnn_learner(data, models.resnet34, metrics=root_mean_squared_error)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.90% [84/706 00:05<00:42 35.3217]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=3e-4

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.738353</td>
#       <td>2.682266</td>
#       <td>1.610911</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.929822</td>
#       <td>1.734174</td>
#       <td>1.296109</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.068235</td>
#       <td>1.594893</td>
#       <td>1.245628</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.687977</td>
#       <td>1.474759</td>
#       <td>1.198055</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.744627</td>
#       <td>1.458652</td>
#       <td>1.191442</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('summed_thirds-stage-1')

# %%
learn.load('summed_thirds-stage-1');

# %%
preds_summed_thirds = learn.get_preds()

# %%
validation['summed_thirds_actual'] = preds_summed_thirds[1].T.tolist()
validation['summed_thirds_predicted'] = preds_summed_thirds[0].T.tolist()[0]
validation['summed_thirds_error'] = validation['summed_thirds_actual'] - validation['summed_thirds_predicted']

# %% [markdown]
# # Error Analysis

# %% [markdown]
# ### Three columns for the 8 models, each trained on a different target variable

# %%
validation.head()
# Out:
#    average_rating_actual  average_rating_predicted  average_rating_error  \
# 0                   3.19                  3.869111             -0.679111
# 1                   3.93                  3.913237              0.016763
# 2                   3.73                  3.861418             -0.131418
# 3                   3.68                  3.951411             -0.271411
# 4                   3.78                  3.879087             -0.099087
#
#    average_rating_mean_norm_actual  average_rating_mean_norm_predicted  \
# 0                        -2.156091                           -0.178756
# 1                        -0.017703                           -0.033645
# 2                        -0.595645                           -0.110103
# 3                        -0.740131                            0.152656
# 4                        -0.451160                           -0.172110
#
#    average_rating_mean_norm_error  average_rating_min_max_actual  \
# 0                       -1.977334                          0.638
# 1                        0.015943                          0.786
# 2                       -0.485542                          0.746
# 3                       -0.892787                          0.736
# 4                       -0.279049                          0.756
#
#    average_rating_min_max_predicted  average_rating_min_max_error  \
# 0                          0.779590                     -0.141590
# 1                          0.787504                     -0.001504
# 2                          0.788915                     -0.042915
# 3                          0.786955                     -0.050955
# 4                          0.774076                     -0.018076
#
#    average_rating_thirds_actual         ...         ratings_count_error  \
# 0                             0         ...                  242.910259
# 1                             1         ...                42680.130302
# 2                             0         ...                 4362.384336
# 3                             0         ...                   31.549915
# 4                             0         ...                  343.268547
#
#    ratings_count_log_actual  ratings_count_log_predicted  \
# 0                  5.556828                     5.669161
# 1                 10.662001                     8.425425
# 2                  8.383662                     6.245042
# 3                  3.951244                     4.988267
# 4                  5.872118                     4.953963
#
#    ratings_count_log_error  ratings_count_thirds_actual  \
# 0                -0.112333                            1
# 1                 2.236576                            2
# 2                 2.138620                            2
# 3                -1.037023                            0
# 4                 0.918155                            1
#
#    ratings_count_thirds_predicted  ratings_count_thirds_error  \
# 0                               1                           0
# 1                               2                           0
# 2                               1                           1
# 3                               0                           0
# 4                               0                           1
#
#    summed_thirds_actual  summed_thirds_predicted summed_thirds_error
# 0                   1.0                 1.870722           -0.870722
# 1                   3.0                 2.273115            0.726885
# 2                   2.0                 2.093298           -0.093298
# 3                   0.0                 1.095698           -1.095698
# 4                   1.0                 1.649893           -0.649893
#
# [5 rows x 24 columns]

# %%
validation.describe()
# Out:
#        average_rating_actual  average_rating_predicted  average_rating_error  \
# count            2119.000000               2119.000000           2119.000000
# mean                3.950793                  3.908533              0.042260
# std                 0.333371                  0.151398              0.356036
# min                 0.000000                  3.347210             -3.958106
# 25%                 3.800000                  3.803509             -0.133880
# 50%                 3.980000                  3.903531              0.066188
# 75%                 4.140000                  4.002146              0.255539
# max                 5.000000                  4.610054              1.105941
#
#        average_rating_mean_norm_actual  average_rating_mean_norm_predicted  \
# count                      2119.000000                         2119.000000
# mean                          0.042383                            0.033464
# std                           0.963347                            0.351598
# min                         -11.374277                           -1.206967
# 25%                          -0.393365                           -0.192216
# 50%                           0.126783                            0.019397
# 75%                           0.589137                            0.262867
# max                           3.074291                            1.696287
#
#        average_rating_mean_norm_error  average_rating_min_max_actual  \
# count                     2119.000000                    2119.000000
# mean                         0.008918                       0.790159
# std                          1.007060                       0.066674
# min                        -11.383304                       0.000000
# 25%                         -0.506011                       0.760000
# 50%                          0.082926                       0.796000
# 75%                          0.625181                       0.828000
# max                          3.282647                       1.000000
#
#        average_rating_min_max_predicted  average_rating_min_max_error  \
# count                       2119.000000                   2119.000000
# mean                           0.782875                      0.007283
# std                            0.017951                      0.067306
# min                            0.702730                     -0.786154
# 25%                            0.771268                     -0.025310
# 50%                            0.782983                      0.012116
# 75%                            0.794072                      0.047171
# max                            0.850754                      0.235816
#
#        average_rating_thirds_actual         ...           \
# count                   2119.000000         ...
# mean                       1.035394         ...
# std                        0.803188         ...
# min                        0.000000         ...
# 25%                        0.000000         ...
# 50%                        1.000000         ...
# 75%                        2.000000         ...
# max                        2.000000         ...
#
#        ratings_count_predicted  ratings_count_error  ratings_count_log_actual  \
# count              2119.000000         2.119000e+03               2119.000000
# mean                  6.218357         2.042077e+04                  6.602323
# std                  13.731600         1.600126e+05                  2.671358
# min                 -36.619640        -2.519406e+01                  0.000000
# 25%                  -2.665255         1.101177e+02                  4.736198
# 50%                   7.034238         7.309279e+02                  6.599871
# 75%                  15.882703         4.613219e+03                  8.438034
# max                  44.844086         4.597635e+06                 15.341060
#
#        ratings_count_log_predicted  ratings_count_log_error  \
# count                  2119.000000              2119.000000
# mean                      6.536265                 0.066058
# std                       1.457815                 2.512255
# min                       0.245615                -7.859217
# 25%                       5.680943                -1.681291
# 50%                       6.535461                 0.076580
# 75%                       7.440805                 1.876979
# max                      11.190114                 8.684795
#
#        ratings_count_thirds_actual  ratings_count_thirds_error  \
# count                  2119.000000                 2119.000000
# mean                      0.991977                   -0.078811
# std                       0.806274                    1.051066
# min                       0.000000                   -2.000000
# 25%                       0.000000                   -1.000000
# 50%                       1.000000                    0.000000
# 75%                       2.000000                    1.000000
# max                       2.000000                    2.000000
#
#        summed_thirds_actual  summed_thirds_predicted  summed_thirds_error
# count           2119.000000              2119.000000          2119.000000
# mean               2.027371                 1.890395             0.136976
# std                1.181461                 0.406282             1.200237
# min                0.000000                 0.088018            -2.820401
# 25%                1.000000                 1.639058            -0.767454
# 50%                2.000000                 1.892482             0.153793
# 75%                3.000000                 2.143487             1.070527
# max                4.000000                 3.246280             3.027336
#
# [8 rows x 22 columns]

# %%
validation.columns
# Out:
# Index(['average_rating_actual', 'average_rating_predicted',
#        'average_rating_error', 'average_rating_mean_norm_actual',
#        'average_rating_mean_norm_predicted', 'average_rating_mean_norm_error',
#        'average_rating_min_max_actual', 'average_rating_min_max_predicted',
#        'average_rating_min_max_error', 'average_rating_thirds_actual',
#        'average_rating_thirds_predicted', 'average_rating_thirds_error',
#        'ratings_count_actual', 'ratings_count_predicted',
#        'ratings_count_error', 'ratings_count_log_actual',
#        'ratings_count_log_predicted', 'ratings_count_log_error',
#        'ratings_count_thirds_actual', 'ratings_count_thirds_predicted',
#        'ratings_count_thirds_error', 'summed_thirds_actual',
#        'summed_thirds_predicted', 'summed_thirds_error'],
#       dtype='object')

# %% [markdown]
# ### Comparing the distribution of actual vs predicted for the regression models

# %%
def book_cover_distplot(title, data1, data2):
    sns.set()
    sns.set_style('ticks')
    sns.distplot(data1, label='actual')
    sns.distplot(data2, label='predicted')
    plt.legend()
    plt.title(title)
    plt.xlabel('')
    sns.despine()

# %%
book_cover_distplot('Average Rating', validation['average_rating_actual'], validation['average_rating_predicted'])

# %%
book_cover_distplot('Average Rating Mean Norm', validation['average_rating_mean_norm_actual'], validation['average_rating_mean_norm_predicted'])

# %%
book_cover_distplot('Average Rating Min Max', validation['average_rating_min_max_actual'], validation['average_rating_min_max_predicted'])

# %%
book_cover_distplot('Ratings Count', validation['ratings_count_actual'], validation['ratings_count_predicted'])
plt.xlim(-5, 1000);

# %%
book_cover_distplot('Ratings Count Log', validation['ratings_count_log_actual'], validation['ratings_count_log_predicted'])

# %%
book_cover_distplot('Summed Thirds', validation['summed_thirds_actual'], validation['summed_thirds_predicted'])

# %% [markdown]
# ### Generating confusion matrices for the classification models

# %%
learn.load('average_rating_thirds-stage-1')
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_confusion_matrix(title='Average Rating Classification')

# %%
learn.load('ratings_count_thirds-stage-1')
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_confusion_matrix(title='Ratings Count Classification')

# %% [markdown]
# ### Rating Count Classification looks the least bad (42% accuracy); all other models center heavily around the mean. Next step: reloading the CNN and doing additional training

# %% [markdown]
# # Additional Training

# %% [markdown]
# ### Reload the number of ratings segment CNN classifier

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('ratings_count_thirds')
        .transform(size=(192, 128), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))  
learn = cnn_learner(data, models.resnet34, metrics=accuracy)
learn.load('ratings_count_thirds-stage-1');

# %% [markdown]
# ### Unfreeze the earlier resnet layers

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.04% [85/706 00:09<01:07 3.5978]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# ### Train the full CNN for 2 epochs

# %%
learn.fit_one_cycle(2, slice(4e-5, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.073790</td>
#       <td>1.054939</td>
#       <td>0.437470</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.907857</td>
#       <td>1.050581</td>
#       <td>0.460123</td>
#       <td>01:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('ratings_count_thirds-stage-2')

# %%
learn.load('ratings_count_thirds-stage-2');

# %% [markdown]
# ### Recreate the dataset using larger images

# %%
data = (ImageList.from_df(cover_df, './data/Grant/cover_images', cols='file_name')
        .split_by_rand_pct(seed=42)
        .label_from_df('ratings_count_thirds')
        .transform(size=(384, 256), padding_mode='reflection', resize_method=ResizeMethod.PAD)
        .databunch(bs=12).normalize(imagenet_stats))  

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 384, 256])

# %% [markdown]
# ### Refreeze and train the last couple layers

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='706', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.76% [83/706 00:15<01:55 3.3669]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(3, slice(2e-5, 2e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.119444</td>
#       <td>1.129642</td>
#       <td>0.428032</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.038796</td>
#       <td>1.082251</td>
#       <td>0.430864</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.003637</td>
#       <td>1.062213</td>
#       <td>0.443605</td>
#       <td>02:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### View loss over time

# %%
learn.recorder.plot_losses()

# %% [markdown]
# ### Plot of the top losses

# %%
interp.plot_top_losses(9, figsize=(10,11))

# %% [markdown]
# ### Based on the Confusion Matrix, it looks like the worst mistakes (e.g. predicts a 2 but the actual is 0) are the least frequent

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_confusion_matrix(title='Ratings Count Classification')

# %% [markdown]
# ### Save and export this model with a 44% accuracy rate

# %%
learn.save('ratings_count_segment-256-stage-1')

# %%
learn.export()
